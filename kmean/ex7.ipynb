# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from kmean import kmean
from scipy import io

# %%
data = io.loadmat("/home/sjl/桌面/machine learning/mlclass-ex7-005/mlclass-ex7/ex7data2.mat")
X = data['X']

# %%
k = kmean(3, X)

# %%
centroid, cluster = k.fit()

# %%
# 显示聚类结果
def displayCluster(X, K, cluster):
    for i in range(K):
        indexs = np.nonzero(i == cluster[:, 0])[0]
        x = X[indexs]
        plt.plot(x[:, 0], x[:, 1], 'o')
    plt.show()
displayCluster(X, 3, cluster) # correct

# %%
# 图像压缩
bird = plt.imread('/home/sjl/桌面/machine learning/mlclass-ex7-005/mlclass-ex7/bird_small.png')
plt.imshow(bird)
plt.show()

# %%
reduceBird = bird.reshape(-1, 3)

# %%
k = kmean(16, reduceBird)
centroid, cluster = k.fit()
# Out:
# /usr/local/lib/python3.5/dist-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:73: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e66a7055c37b> in <module>()
#       1 k = kmean(16, reduceBird)
# ----> 2 centroid, cluster = k.fit()
#
# ~/桌面/CoCo/kmean/kmean.py in fit(self)
#      59                     minIndex = -1
#      60                     for k in range(self.K):
# ---> 61                         distance = self.calDistance(self.X[i], centroid[k])
#      62                         if distance < minDistance:
#      63                             minDistance = distance
#
# ~/桌面/CoCo/kmean/kmean.py in calDistance(self, x, u)
# ...

# %%
for k in range(16):
    reduceBird[np.nonzero(cluster[:, 0]==k)[0]] = centriod[k]
compressBird = refuceBird.reshape((28, 28, 3))
plt.imshow(compressBird)
plt.show()
